# %%
import pytesseract
from PIL import Image
import xlsxwriter 
from os import listdir
from os.path import isfile, join
#this logic can processes any ammount of 
data_path="C://Users//HP//Desktop//RC//"        
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]
        
for i, files in enumerate(onlyfiles):
    image_path = data_path + onlyfiles[i]
    img = Image.open(image_path)
    text=pytesseract.image_to_string(img,lang="eng")
    text=text.upper()
    print(text)
    print("============================")
# Out:
# }Z299V961D : ON“ NO3Y
# ============================
# REGN . NO : DL9CAC6215
#
# OSNO_ : OT
# REG. DT: 24/42/2012 MFG CD: MUL
# CH.NO : MA3FHEB1S00358580 COLOUR : PMAWHITE
# ENO : D13A0338461 CLASS: LM.
#
# NAME _: SRISHTI NAYAR
#
# SSIWID OF : SANJIV NAYAR
#
# ‘ADDRESS: 80C BLOCK NEELAMBER APTS
# RANI BAGH
#
# NEW DELH! 110034
#
# : SWIFT VDI BS4M REGISTERING AUTHORITY
# ‘ NO.OF CYL =. 4 PALAM
# UNLADEN WT : 1060
# SEATINGC, : 5
# STANDING C =
# CU.CAP 2 1248
# ============================
# REGN. NO: D
#
# REGN DT: 21/07/2015 CHINO : MA3ETDE1S00218363
#
# OSNO :01 ENO : 7567094
#
# COLOUR : GLISTENINGGREY MFR MARUTI SUZUKI INDIA LTD
# VEH CL : MOTOR CAR
#
#
#
# L2CAT9109"=
#
# OFAN NAME ANOOP SURESH DHAWALE
# MAH } SMWID OF : SURESH HARISHCHANORA DHAWALE
# : J}, ADDRESS : 72 SHRI BADRINATH APPTT,PLOT NO-18
#
# SEZ SEC-4 DWARKA NEW DELHI,,SOUTH WEST,
# DELHI-110075
# MODEL MARUTI CELERIO VXI GREEN
# BODY RIGID (PASSENGER CAR)
#
# WHEEL BASE : 002425 NOOFCYL 03 AAGEG—
# MFG OT 07/2015 UNLADEN WT
#
# FUEL PETROLICNG SEATING C 005
#
# REGDUPTO : 20/07/2030 STANDING . 00
#
# TAXUPTO  : OTT CU CAP C00SES 26 ANAOIG A
# ============================
# GOVERNMENT OF HARYANA TRANSFER OF OWNERSHIP
# & CERTIFICATE OF REGISTRATION OF MOTOR FORM NO. 23 RULE 48
# VEHICLE
#
# EHICLE LM. (CAR) OWNER SERIAL 2
# SALOON ‘MONTH AND YEAR OF MIG. 912006
# BESLER NAME AND ADDRESS HARISONS AUTOMOBILES,G.7.ROAD PANIPAT
# MAKE MARUTI LID ‘COLOR OF BODY $.SIL
# ‘MAKER CLASSIFICATION “ALTO LXIB.S. LIT SSE EMCEES 796
# A NO.OF CYLINDERS 3
# ~ FUEL USED |
#
# ENGINE F8DN3321864 EE
# GV. WEIGHT 1165 KGS VALID FROM07-FEB-2007 VALID UPTO 05-DEC-2024
#
#
#
#
#
# AE COON
# ============================
# GOVERNMENT OF HARYANA TRANSFER OF OWNERSHIP
# & CERTIFICATE OF REGISTRATION OF MOTOR FORM NO. 23 RULE 48
# VEHICLE
#
# CUCRNMAUECES”* (5°31
# SPW OF  MEHRU
#
# ES
# FULL ADDRESS VIT ACE SPING A GUJRAN, TEH. BAPOLIP)
#
#
#
#
#
#
#
#
# J
# CLASS OF VEHICLE LM.V. OWNER SERIAL 2 |
# TYPE OF BODYS600L PULLMAN MONTH AND YEAR OF MIG. 1112008 |
# DEALER NAME AND ADDRESS OTHE!
# MAKE _ MARUTIUDYOG LTD QOLEROF BODY WARE |
# MV I HORSE POWEB.HP) 796 |
# ‘NO.OF CYLINDERS 3
# ============================
# CERTIFICATE OF REGISTRATION OF MOTOR FORM NO. 23 RULE 48
# VEHICLE
#
#
#
#
#
#
#
#
#
#
#
#
#
# 5 ‘ GOVERNMENT OF HARYANA
#
# REGISTRATION NO. HR49D 0002
# OWNER'S NAME AMAR NATH
# S/D/W OF BARU RAM
#
# FULL ADDRESS |4.NO.15, AGGARSAIN, COLONY,,PANIPAT,
#
# CLASS OF VEHICLE LLM. (CAR) OWNER SERIAL 1
#
# TYPE OF BODYNOTCHBACK MONTH AND YEAR OF MFG. 9/2013
# DEALER NAME AND ADDRESS HARISONS S,
#
# MAKE — MARUTI SUZUKI INDIA LTD. COLOR OF BODY P MA WHITE
#
# MAKER CLASSIFICATION MARUTI SWIFT DZIRE VDI HORSE POWER(BH.P.) 55.2
# CHASSIS NO. MA3FJEB1$00404062 NO.OF CYLINDERS 4
#
# ENGINE D13A2235550 FUEL USED DIESEL
#
# G.V. WEIGHT 1505 KGS VALID FRONM13-NOV-2013 VALID UPTO 08-OCT-2028
#
#
#
#
#
#
# 03.81.2017
# EE
# ============================
# ~ NE
#
#
#
# = GOVERNMENT OF HARYANA
# © CERTIFICATE OF REGISTRATION OF MOTOR FORM NO. 23 RULE 48
# A VEHICLE
#
# F HRC H1768
#
# OWNER'S NAME MR HARISH KUMAR
#
# S/W OF S/O SH. KESHO RAM
#
# FULL ADDRESS 4 NO, 92/12, DESHRAJ COLONY, GALI NO. 7,PANIPAT, 132103
#
# ¢ T LUMLV. (CAR) OWNER SERIAL 1
#
# TYPE OF BODYSALOON MONTH AND YEAR OF MFG. 4/2016
# DEALER NAME AND ADDRESS HARISONS AUTOMOBILES,G.T.ROAD,PANIPAT
# MAKE MARUTI SUZUKI INDIA LTD. COLOR OF BODY GRANITE GREY
# MAKER CLASSIFICATION ERTIGA GREEN VX! HORSE POWER(B.H.P.) 88
# CHASSIS NO, MASELMG1800384268 NO.OF CYLINDERS 4
#
# ENGINE \K14BN 7124699 FUEL USED PETROLICNG
#
# G.V. WEIGHT 1820 KGS VALID FROM06-MAY-2016 VALID UPTO07-APR-2031
# ============================
# GOVERMIENT OF HARYANA
# @ CERTIFICATE GF REGISTRATION OF MUGTOR FORM HE. 23 RUE 46
# VEE
#
# ASGISTRATION NA. HRIKK 6656
# OUTER S MARIES PAM KANARS
# SAW OF SHI PARAS
#
# FULL NAMES 44 54, 922115, GANOMI WAGER GANAUR SOMPRT.
#
#
#
# CLASS OF VEHICLE SAM .
# [1P A BG WOTONBROK GETT A
# LESTE: MARTE A HIDDIE
# MASAITI SUZLNS IIA LTD, A
# MAST SGRCOT ENS ) 62
# ENGRS IC A 7208067 MAOH CINDERS &
# 7 FUEL USED BIESEL,
#
# GY WEIGHT 1808 AYS VALID FA .
#
# 03.01 2017
# ============================
# GOVERNMENT OF HARYANA
# CERTIFICATE OF REGISTRATION OF MOTOR FORM NO. 23 RULE 48
# VEHICLE
#
#
#
#
#
#
# REGISTRATION NO. HROGAER243
#
# OWNER'S NAME MR VINAY KUMAR HANDA
#
# S/OIN OF PROP, W/S SHIVA WOOLEN
#
# FULL ADDRESS WOUSTRIES, HNO. 927, SEC-12 PHASE-2, HUDA,PANIPAT, 132103
# —
#
# CLASS OF VEHICLE L.M.V. (CAR) OWNER SERIAL 1
# _ TYPE OF BODYCAR (SEDAN) MONTH AND YEAR OF MFG. 1/2015
# DEALER NAME AND ADDRESS HARISONS AUTOMOBILES,G.T.ROAD,PANIPAT
# MAKE MARUTI SUZUKI INDIA LTD. COLOR OF BODY WHITE
# MEER CLASSIFICATION SWIFT OZIRE VXI BS IV HORSE POWER(B.H.P.) 76
# - CHASSIS NO. MA3EJKD1$00683213 NO.OF CYLINDERS 4
# ENGINE 12MIN 1630003 FUEL USED PETROL
#
# GV. WEIGHT 1460 KGS VALID FROM@-FEB-2015 VALID UPTO 28-JAN-2030
#
#
#
# 03.01.2017
# ============================
# GOVERNMENT OF HARYANA
# CERTIFICATE OF REGISTRATION OF MOTOR FORM NO. 23 RULE 48
# VEHICLE {
# REGISTRATION NO. HROGAK2102
# OWNER'S NAME MR. JITENDER
# S/D/W OF — SH. SATPAL SINGH
# FULL ADDRESS 41 NO. 20, BLOCK NO. 2, ISRANA,PANIPAT, 132103
#
# CLASS OF VEHICLE L.M.V. (CAR) OWNER SERIAL 1
#
# TYPE OF BODYSALOON MONTH AND YEAR OF MFG. 9/2016
# DEALER NAME AND ADDRESS HARISONS T
# MAKE MARUTI SUZUKI INDIA LTD. COLOR OF.
#
# MAKER CLASSIFICATION SWIFT VDI BS IV HORSE POWER(B.H.P.) 86
# CHASSIS NO, MA3FHEB1S00B52684 NO.OF CYLINDERS 4
#
# ENGINE 0D13A2899227 FUEL USED DIESEL,
#
# G.V. WEIGHT 1605 KGS VALID FRORM6-NOV-2016 VALID UPTO 20-OCT-2031
#
# 03.81.2017
# ============================
# REGN. NO : DL2CAU7997
#
#
#
# REG.DT —-: 02/08/201 OSNO :O1
# CH.NO : MA3FLEB1S00309631 MFG CD. MSILTD
# ENO + D13A2554860 C : SERENE BLU
# CLASS = LM.
# OS : MANJEET SINGH
# HI A A1 OF : JOGINDER SINGH
# PO} ADDRESS : 8-147
# MANSAROVER GARDEN
# NEW DELHI 110015
#
# ERTIGA ZDI (M)
# SALOON
# ============================
# REGN . NO :DL2CAS1294
#
# OSNO_ : %
# REG. DT: 1805/2013
# CHINO’ MFG CD MUL
# ENO : K12MN1262837
#
# NAME : MR. ANIK NARULA
#
# SIWID OF : SH. RAJAN NARULA
#
# ADDRESS: B-169, BLOCK-B
# NEW MOTI NAGAR
#
# NEW DELHI
# L: SWIFT DZIRE VXI BS4_M
# BODY ; GALOON NO.OF CYL_: 4
# WHEEL : AE EE
# > 05/2013 =
# MFG.DT. : STANDINGG > __
# E CU.CAP : 4497
#
#
#
#
#
#
#
#
# TP AVONKOS
# ============================
# REGN . NO: DL3CBU4111
#
#
#
#
#
#
#
#
# OSNO
# REG. DT: 12 MFGCD : MUL
# CH. NO : MA3FDEB1200381622 COLOUR : S. SILVER
# ENO : D13A1833010 CL : LM.
# NAME _: SAURABH JAIN
#
# S/WID OF : SUMAN CHANDRA JAIN
#
# ADDRESS: FLAT NO. 23 RESIDENT DOCTORS
# HOSTEL SAFDARJUNG HOSPITAL
# NEW DELHI 110029
#
# MODEL : RITZ VDI MBSS
# BODY : SALOON
#
# REGISTERING AUTHOR?
# NO.OFCYL : 4 SHEIKH CANT
# UNLADEN WT : 1410
# SEA 2 6:
# STANDINGC :
# CUL.CAP : 1248
# ============================
# REGN . NO : DL13CA8614
#
# REG. DT: 11/02/2014
# CH. NO : MA3FHEB1S00593004
# ENO : D13A- 2307158
#
# NAME : RAKESH KUMAR
# S/WID OF : SHRI SOM NATH
# ADDRESS: H NO -60 IIIRD FLOOR STREET
# NO -2/3 ARJUN NAGAR
# DELHI 110051
#
# : SWIFT LDIBS4M
# : SALOON
#
# ISTERING A\
# ‘SURAJMAL VIHAR
#
# A0
#
# > 01/2014 H
#
# : DIESEL STANDINGC :
# 4 CU.CAP US
#
# ORT
# ============================
# ADDRESS: R-24
# SOUTH EXTN IT
#
# NEW DELHI
# HPILEASE:
# MODEL ALTO K10 LXI BS4
# BODY SALOON NO.OFCYL : 3
# WHEEL BASE: 0 MI
#
# UNLADEN WT
# MFG.DT 05/2041 SEATING C
# FUEL PETROL EAE C
# ============================
# REGN. NO : DL8CAN1006"™”
#
#
#
# REGN DT: 07/05/2016 CH NO : MA3EHKD1S00A97129
# OSNO O1 ENO : 1774707
# “| COLOUR : ARCTIC WHITE VEH CL : MOTOR CAR
# MFR : MARUTI SUZUKI INDIA L
# TO
# A \ NAME : SACHIN KUMAR
# IES SIWID OF =: JAIPARKASH SINGH
# 3} | ADDRESS : F 46 NORTH GHONDA GAL! NO 4F BLOCK
#
# SUBHASH VIHARNORTH EASTDL110053
#
# MODEL MARUTI SWIFT VX! BSIV
# BODY RIGID (PASSENGER CAR)
#
# WHEEL BASE : 002430 WD
#
# UNLADEN WT : 000945
#
# MFG OT 05/2016
#
# FUEL PETROL : ORATE SS 0S SIGNATURE
#
# REGD UPTO 21106203" REGISTERING AUTHORITY
# CU CAP 001197 WAZIRPU!
#
#
#
# TAX UPTO ORT
#
# 25B-AZ DONG
# ============================
# = — EEE
#
# < REGN. NO: DL9CAE2930 30" - I
# REGN OT: 1370972015 CH NO - MA3FE
# ©SNO 01 ENO S9715
# COLOUR GLISTENINGGREY MFR U
# VEH CL
# KARA
# VAY F
# 195, PAT TRO EXTN_SEC-21_NE
# W DEIHI DETH:-1 10085
#
#
#
#
#
# RUT! SUZUKI IN
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# MARUT! SWIFT LDI BSIV
#
# BODY RIGID (PASSENGER CAR)
#
# NO OF CYL 04 WHEEL BASE - 00:
#
# MFG OT 08/2015 UNLADEN WT : 001
# OIESEL SEATINGC =:
#
# 05/10/2030
# ============================
# REGN. NO : DL8CAH3172
#
# REG. DT » 24/11/2014 OSNO :01
# CH. NO : MA3ETDE1S00159552 MFG CD: MUL
#
# M =NO K10BN7417497 COLOR : PMA.WHITE
# CLASS : L.M.V
#
# : CHANDRA BHUWAN KUMAR
#
# : NARENDRA PRASAD
#
# H NO.5-6 KH NO.4821/22 BLOCK-B
# DHIRAJ VIHAR KARALA
#
#
#
#
#
#
#
#
#
#
#
#
#
# DELHI 110081
# MODEL CELERIO VXI GREEN M BS4
# BODY : SALOON NO.OFCYL :3
# WHEEL BASE : 0 UNLADEN WT : 915
# | MFG. DT. : 10/2014 SEATINGC :5
# F FU : ¢
# EL PETCNG STANDING C SIGN:
#
#
#
#
#
# CU.CAP : 998
#
#
#
# REG UPTO: 23/11/2029
# TAX UPTO : OTT
# ============================
# REGN. NO : DL5CJ 7852
#
# REG. DT: 17/05/2014 OSNO :01
# CH.NO : MA3FJEB1S00528720 MFG CD : MUL
# ENO : D13A2368228 COLOR : A.WHITE
# CLASS :L.M.V.
# NAME : MEGHNA AGGARWAL
# SMWID OF : MR.RAJNEESH AGGARWAL
# ADDRESS : H.NO-6/49/2 STREET NO-2 KUNT! MARG
#
# VISHWAS NAGAR SHAHDARA
#
# DELHI 110032
# MODEL : SWIFT DZIRE VDI BS4
#
# BODY : SALOON NO.OFCYL :4
# WHEEL BASE : 0 UNLADEN WT : 1060
# MFG. DT. : 04/2014 SEATINGC :5
# FUEL : DIESEL STANDING C :
# SIGNATURE
# REG UPTO 16/05/2029 CU.CAP 1248 REGISTERING AUTHORITY
#
# A LONI RD,NEZ
# ============================
# A
#
#
#
# - 5 REGN . NO : DL5CJ 5387
# V MS OO OSNO 04
#
# MFG CD : MUL
# COLOUR : AWHITE
# CLASS: LM.
#
# : HITESH NAGAR
# 'SH.SUDHRAM NAGAR
#
# : AAMBA-1 BLOCK
# MADHU VIHAR
#
# 410037
#
# REGISTERI
# LONT ROAD
#
# DEE
#
# ‘SIGNATURE
# ============================
# REGN . NO : DL8CU 7889
#
# OSNO_ =: OF
# REG. DT: 14/02/2013 MFGCD : MUL
# CH. NO : MA3EUA61S00170565 COLOUR : S. WHITE
# ENO =: F8DN4958005 CLASS -: LMV.
#
# NAME : MAMTA GOEL
#
# SNWID OF : ANIL KUMAR GOEL
#
# ADDRESS: HOUSE NO-51 SEC-9
# RISH? APPTT ROHINI
#
# NEW DELHI
#
# MODEL -: ALTO S800LXIBS IV
#
# BODY | : SALOON NO.OF CYL =: 3
# WHEEL BASE: 0 UNLADEN WT : 720
# MFG.DT. : 422012 SEATINGC : 5
# FUEL : RCNGIP STANDING C :
# REG.UPTO : 13/02/2028 $CU.CAP : 796
#
# TAX UPTO : OTT
# ============================
# . ALTIMPTIHP,
# REGN. NO : DL&CN 3195
# REG, DT: 30/11/2013 OSNO :01
# CH. NO: MA3EWDE1S00637165
# ENO  : K10BN4590508
#
#
#
# NAME : KARISHMA DHAWAN
#
# SMWID OF : VINEET DHAWAN
#
# ADDRESS : 193 POCKET-1
# SECTOR-23 ROHINI
#
#
#
# DELHI 110085
# MODEL : PESAGE CH R A LXI M BS4
# ============================
# REGN . NO: DL5CJ 4987
#
# OSNO_ : 01
# REG. DT: 12/04/2013 MFGCD : MUL
# ’ CH.NO : MA3EWDE1S00526415 COLOUR : S.WHITE
# ENO : K10BN7228183 CLASS : LM.
#
# SIWID OF > MR.SANJAY VERMA
# ADDRESS: A-1/399,MADHU VIHAR RAJA PUR!
#
# DELHI
#
# MODEL : WAGON R GREEN LX! BS4
# : SALOON
#
# BODY : NO.OFCYL : 4
# WHEEL BASE : 0 UNLADEN WT : 960
# MFG.DT. : 0212013 SEATINGC : 5
# FUEL : PETCNG STANDING C :
# REG.UPTO =: 11/04/2028 CU.CAP : 998
#
# TAX UPTO : OTT
# NIEN
# ============================
# REGN . NO : DL8CP 6677
# ON BS PASE }S00175677 COLOUR: : BO CON AY
# ENO - KT2MN4034468 CLASS) = LY
# ============================
# RIGAAISI3
# 3 RAJ
# 40. 8/18, BRAHAM COLONY NR, DEEPAK, MANDIR.SONIPAT,
#
# 2 LM. (CAR) OWNER SERIAL 1
# TYPE OF BODYSALOON MONTH
#
# AND ¢
# IAN MOTORS LTD,,,SONIPAT
# ‘OF BODY M
# ============================
# NO : DL9CX 3096
#
#
#
#
#
#
#
#
#
#
# ALT
#
# BOAS SNO_ : 01
# REG. OF: 26/09/21 MFG CD : MUL
# CH. NO MA3EFJC1S0151460 COLOUR : SSILVER
# ENO : M16AN2011764 CLASS: LM.
# NAME : MANOJ VERMA
# SIWID O} SANTOSH KUMAR
# ADDRESS: RZF-14
# WEST SAGAR PUR
# NEW DELHI 110046
# . HP/LEASE: HDFC BANK LTD
# MODEL : SX4VXIBS3 REGISTERING AUTHORITY
# > SALI NO.OF CYL : 4
# WHEEL BASE : 0 UNLADEN WT : 1200 “
# MFG.DT. + 08/2009 SEATINGC  : 5
# FUEL > RCNGIP STANDING C : S
# REG.UPTO .: 25/09/2024 = CU.CAP. 2 1586
# JAXUPTO =: OTT SE
#
# NCIC AEYAUN IE)
# ============================
# REGN. NO : DL1CUS248 *”
#
# FECA” (44ERS H~EO MESES H2ESESZE
# CC SAP BD = MO ZZR 2
# COLO SPSS CSE OE TOYOTA GRLOGHAS MOTOR PT LT
# VEX CL METER CAR
# WB WE SIRES OLIMAP GOYAL
#
# SE CR MANGE FEM
# SCOPESS 8 {MT NEAR POTAMPURA METRO STATION
#
# RASA STHAL) APPARTMENT PTAMPURA
# OW OETWOL | 10034
#
# WCCEL CORCLLA AL TIS 186 (CC)
#
# B00Y SEDAN
#
# NO OF CYL AD WHEEL BASE - COZ7700
#
# MFG OT O172016 UNLADEN WT - GO1270
#
# FUEL PETROL SEATING C 20S
#
# REGO UPTO 2202031 STANDING C MY
# TAX UPTO ORR CU CAP COR7SG EGSTENNG :
# ============================
# S20’
#
# MOC TL EECO 5 STR VC+H" RM BS4
#
# > SALOON WO.CF CYL
# “S1EL1 BASE: V
# MFG OD)
#
# WR
# OWFND SEATING C
# PRUE. ROR »P
#
# ME
# ============================
# REGN . NO : DL5CJ 6088
#
# REG. DT: 06/10/2013 MEE 5 MUL
# CH. NO : MA3FHEB1S00520199 COLOUR : G.GREY
# ENO —: D13A2235055 CLASS: L.MV.
# NAME _: RAJNISH JAIN
# SIWID OF : SH.SURESH CHAND JAIN
# ADDRESS: 1/5987,KABOOL NAGAR
# EAST ROHTASH NAGAR
#
# DELHI 110032
#
# MODEL =: SWIFT VDIBS4M REGISTERING AUTHO!
#
# BOI : SALOON NO.OF CYL: 7 LONI ROAD
# UNLADEN WT : ON AS
# SEATING C
#
# STANDING C :
# CU.CAP :
# TAX UPTO: OTT : EAT
# ============================
# A
#
# REGN . NO : DL2CAM0993
#
# P OSNO_ -: OF
# REG. DT: 13/70/2010 MFGCD : HYU
#
# CH.NO : MALBB51BLAM217697 COLOUR : (CR. WHITE
# ENO -: G4LAAM4SSOSS CLASS : LMY.
# NAME - MR. KAMAL BHOLA
#
# | SAWID OF : S/O SH. J.C. BHOLA
# ADDRESS: 658, AB BLOCK, IND FLOOR,
#
#
#
# RAMESH NAGAR,
# DELHI 410015
#
# HPYLEASE:
#
# MODEL =<: I20 SPORT REGISTERING AUTHORITY
# BODY - SALOON NO.OFCYL : 4 | P DEPOT :
# WHEEL BASE: 0 UNLADEN WT : 1066 OO :
# MFG.DT. - 982010 SEATINGC : 5 YR
# FUEL - PETROL STANDING C : FG: >
# ============================
# EE
#
#
#
#
#
#
# GOVERNMENT OF INCALL “
# ‘CERTIFICATE OF REGISTRATION.
# (FORM NO. 23 RULE 48) |
#
#
#
#
#
#
#
#
#
#
#
#
# - HN NO. HR42-A-4854
# JAME &*ADDRESS ASHWAN 4:
# OF REGD§ OWNER S/O RAM BHAJ IF
# BHIGAN, TEH.GNR .
# SONIPAT A
# PREVIOUS REGN. NO. N/A | ‘
# . PREVIOUS OWNER N/A %S
# CHASIS NO. MA3EED81S00628175 R
# ENGINE NO. F10DN4452456
#
#
#
# 23/01/2008
#
# (INCLUDING DRIVER)
#
# 14.09.2011
#
# ERE IH :
# IF. (TE E
#
# MONTH/ YEAR OF MANUFACTURE
# EF SEATING CAPACITY 5
# A FUEL USED PETROL
# ============================
# NAME/BRAND OF VEHICLE
# MAKER'S NAME _ ,
# VEHICLE CLASS
#
# NO.OF CYLINDERS
# UNLADEN WEIGHT(KG)
# TYPE OF BODY
#
# H.P.A./ LEASE AGG.
#
# DEALER'S NAME
#
# ADDRESS
#
# REGISTRATION VALID UPTO
# ROAD TAX PAID UPTO
# DATE OF ISSUE
#
#
#
#
# SPECIMEN SIGNATURE —__,
# OF REGD. OWNER HV
#
# RE RE ES I EE NY AH AE
#
# AGES ONES
#
# / WAGNOR,LKI E-1 I}
#
# MARUTI UDYOG LTD.
# LMV(MOTOR CAR)
#
# 4 CUBIC CAPACITY 161CC
# 825K COLOUR S WHITE
# SALOON
#
# MAGMA SHRACHI FIN
#
# JAGMOHAN MOTORS
# SONIPAT
#
# 22/01/2023
# ONE TIME
#
# 10/03/2008
#
# AR
# ============================
# “GOVERNMENT OF F HARYAN OF
# CERTIFICATE OF REGISTRATION 3
#
#
#
#
#
#
# WEE _ (FORM NO. 23 RULE 48) W
#
# * REGISTR ATION NO. HR10-P-0840 | CAE 4 |
# NAME & ADDRESS SANDEEP LAKRA CE
#
# OF REGD. OWNER = S/O. MAHABIR SINGH LAKRA
#
# : 638/29, SUBHASH NAGAR A
#
# . SONIPAT ‘+
#
# PREVIOUS REGN. NO. N/A | EA —
#
# PREVIOUS OWNER N/A : S FF
#
# CHASIS NO..." * MALCG41GLAM255721 * A : : ;
#
# ENGINE NO. G4EB9M256677. A FT
#
# IN - MONTH/ YROF ~ 20/01/2010 . * * SY \
#
# SEATING CAPACITY .§  — (INCLIDING DRIVER; IE
#
#
#
# FUEL USED *  BETEOT’,”
# ============================
# — > TEE
# BRAND OF VEHICLE ACCENT-MT-GLE
# HYUNDAI MOTORS INDIA 1. TD.
# LMV (MOTOR C AR)
# 4 CUBIC CAPACITY 149500
#
# _ 1039K COLOUR GT C WHITE
# SEDAN
#
# SBOP |
# MALWA AUTO SALES ,
# KUNDLI
#
# REGISTRATION VALID UPTO 19/01/2025 -
#
# WI OM TAX PAID UPTO ONE TIME
# ATE OF ISSUE 03/03/2010
#
# : AE
# \- TH 4
#
# SPECI SIGNATURE
# OF REGD. OWNER
#
# I <I’
#
# 4 AF
#
#
#
#
# IN
# ============================
# SAO: OE <> EEE
# PE" J RISSE WH \ OF INS. CO QO
# O1> “NES RAIN™  OANRE VIBE \\N EE AE
# REGN . NO : DL3CAX6515
# REG. DT: 24/04/2009 MEG GD TATAEL
# CH. NO : 607146KRZW00622 COLOUR : SCARLET
# ENO =: 473IDT14KRZPB8819 CLASS : LMLV.
#
#
#
#
# NAME : VIKAS ENGINEERING WORKS
#
# SAWID OF : NA
#
# ADDRESS: R2Z-F/118/5,SHIV PARK
# VILLAGE NANGLO}! JAT
#
# DELHI _ 440044
#
# °
#
#
#
#
#
# MODEL : INDIGO CS LS _ REGISTERING
# BODY : SALOON NO.OFCYL : 4
#
#
#
#
# WHEEL BASE : 0 UNLADEN WT : 1065
# MFG.DT. : 4092008 SEATINGC : 5
# FUEL : DIESEL STANDING C :
#
#
#
#
#
# REG.UPTO =: 23/04/2024 +$|£(CU.CAP 1 1405 |
# TAX UPTO : OTT JJ
# ============================
# REGN . NO : DL3CAX6515
#
# OSNO_ =: 01
# REG. DT: 24/04/2009 MFG CD : TATAEL
#
# CH. NO : 607146KRZW00622 COLOUR : SCARLET
# ENO =: 4735IDTI4KRZPBSS19 CLASS : LMLV.
#
# NAME : VIKAS ENGINEERING WORKS
#
# SAWID OF : NA
#
# ADDRESS: RZ-F/118/5,SHIV PARK
# VILLAGE NANGLO} JAT
#
# DELHI
#
# 14.09.2011 18:14
# ============================
# . EE
# REGN . NO : DL3CAX6515
# REG. DT: 2404/2008 EEN : CAE
# CH. NO - 607146KRZWOO06S72 COLOUR © SCARLET
# ENO - 47SIDT14KRZPBSE19 CLASS ° LMY.
# NAME : VWIKAS ENGINEERING WORKS
#
# SAID OF : HA
#
# 14.09.2011 18:14
# ============================
# REGN .NO: DL2CAF6866
#
# OO SNO. : O2
# MFG CD : MUL
# COLOUR : SILKY SILV
# CLASS : LM.
#
# 400127444
#
# SH WSUBHASH HAND
# + A-T4 MA SEO
# BEHIND HAP MKT JANG EU
# 410000
#
# EAST DELHI
# ISTERING AUTHORITY
# 1 P DEPOT
#
# WO, SS
# 18 G OA
# STANDING C = CSE
#
# SIGNATURE
#
# REG!
# ============================
# REGN . NO: DL2CAF6866
#
# O SNO : O2
# MFG CD > MUL
# 4300127444 COLOUR : SILKY SILV
# ME ENOZISTS CRASS: L. MV.
# NAME : HIMANSH!
# SIWID OF : SH MNS HASH CI CHAND
# ADDRESS: A“ 74 MATHURA ROAD JANG! PURA -B
# BEHIND PRATAP MKT PA UDDIN
#
# REG. DT: 03/04/2006
# CH. NO =
# ENO
#
# EAST DELHI
#
# HPILEASE: A1 ENO LXIBS?
# MODEL: BALENO WO. OF STIG
#
# NLADE!
# SEATING C C
# STANDING
#
# GU. CAP
# ============================
# . OT: 34/01/2005
# : G13BBN 190141
#
# NAME
# SIWID OF :
# ADDRESS:
#
# ICICI BANK LTD.
# ESTEEM VX!
# : SALOON
#
# I
#
# + 04/2005
# PETROL
# 30/01/2020
# E : OTT
#
# DEASE
#
# REGN . NO: DL3CAD3216 ;
#
# NO : MA3EBE41S00 430299
#
# : MAHABIR SINGH
#
# CHANDER BHAN
#
# B-40 IIND FLOOR SANJAY NGR
# MANGOL PUR KALAN
#
# NEW DELHI
#
# ER
#
# OS A
#
# O SNO : 01
#
# MFG CD : MUL
# COLOUR : P. SILVER
# CLASS : L.M.V.
#
# 110085
#
# REGISTERING AUTHORITY
# NO.OF CYL: 4 SHEIKH SARAI
# UNLADEN WT : 875
# FETTER OE :
# STAND! I
#
# CU.CAP : 1298 ,
# ============================
# LICENCE NO. 34984 A 11/01/2008
# NAME. DAVINDER SINGH
# S/D/W/O MOHINDER SINGH
# ADDRESS VPO.NANGAL KHURD
#
#
#
#
#
#
#
# SONIPAT HARYANA
# = DATE OF BIRTH 01/05/1972 BLOOD GROUPO+
# VEHICLE CLASS ER/M. AR/JE
# OY | 2
#
#
#
#
# A A
# AF
# ============================
# GOVERNMENT OF HARYANA
#
# CERTIFICATE OF REGISTRATION
# (FORM NO. 23 RULE 48)
#
# RESITTTION NO. HR10O-P-5470
#
# NAME & ADDRESS ~§ DAVENDER SINGH
#
# OF REGD. OWNER S/O MAHENDER SINGH ;
# VPO. NANGAL KHURD, 2
# DISTT. SONIPAT ;
#
# PREVIOUS REGN. NO. N/A
#
# PREVIOUS OWNER N/A
#
# CHASIS NO. MALCM41VR9M079263* L
#
# ENGINE NO. D4FA9U817848
#
# MONTH/ YR OF 31/12/2009 3 —
#
# SEATING CAPACITY 5 (INCLUDING DRIVER) A
#
# FUEL USED DIESEL E
# ============================
# ‘VAME/BRAND OF VEHICLE
# MAKER'S NAME
#
# VEHICLE CLASS
#
# NO.OF CYLINDERS
#
# LNLADEN WEIGHT(KG)
# TYPE OF BODY
#
# H.P.A./ LEASE AGG.
# DEALER'S NAME
#
# ADDRESS
#
# REGISTRATION VALID UPTO
# VAD TAX PAID UPTO
# DATE OF ISSUE
#
#
#
#
# SPECI SIGNATURE
# OF REED. ¢ OWNER
#
#
#
# VERNA L.5CRDI VGT MT
# HYUNDAI MOTORS INDIA LYD..
# LMV (MOTOR CAR)
#
# 4 CUBIC CAPACITY
# 1099K COLOUR
#
# 1493CC
# HW(CRY.WHITE) HES
#
#
#
#
# SALOON. :
# SYNDICATE BANK NE:
# MALWA AUTO SALES I. 3
# KUNDLI, SONIPAT BITE
# 30/12/2024 |
# ONE TIME
#
# 19/05/2010
# ============================
# RE BAAP
#
# TE O REGISTRATION
#
# ' HRI 0-M-5 657
# ESS.  ANUBHAV JAIN )
# ¥  -SLO UMESH KUMAR JAIN
#
# +. GALI INDER LOK
#
#
#
# KATH MANDI, SONIPAT
#
# N/A
# NIA
# MA3FKEB2S800121766
#
# . 13A0120011 —
# | 29/08/2008
#
# ‘(INCLUDING DRIVER)
#
# 28.09 .2011 13.14
#
#
#
#
#
#
# ‘4
# 2
# OE
# 5
# ============================
# SWIFT DZIRE ZD1 E-3
# “MARUTEUDYOG LTD.
#
# - LMV (MARUTE CAR)
#
# 4 CUBIC CAPACITY § 1298CC
# 4 105IK. COLOUR” PMA WHITE
# /NOTCHBACK PAN I
#
# UNION BAK OF EE
#
# NE N
#
# OF A
# ============================
# - ADITYA GUPTA
#
# > SH RAJESH GURE
#
# : SH SB.WEST ENCLAVE
# PITAMPURA
#
# DELHI
# ============================
